# %% [markdown]
# # **Supervised Learning Models on Import-Export Dataset using Python**
#
#
#
# ---
#
#
#
# ## **PROJECT CONTENTS:**
# - Project Information
# - Description of Data
# - Data Sampling
# - Project Objectives | Problem Statements
# - Analysis of Data
# - Observations | Findings
# - Managerial Insights | Recommendations
#
# ---
#
# ### **1. Project Information**
# - **Title**: Data Exploration with Python using Pandas & Numpy Libraries
# - **Students**:Mohit Agarwal (055024)
# - **Group Number**: 2
#
# ---
#
# ### **2. Description of Data**
# - **Data Source**: https://www.kaggle.com/datasets/chakilamvishwas/imports-exports-15000
#
#   A live link is used in the dataset
#
# - **Data Columns Description**:
#   - **Transaction_ID**: Unique identifier for each trade transaction.
#   - **Country**: Country of origin or destination for the trade.
#   - **Product**: Product being traded.
#   - **Import_Export**: Indicates whether the transaction is an import or export.
#   - **Quantity**: Amount of the product traded.
#   - **Value**: Monetary value of the product in USD.
#   - **Date**: Date of the transaction.
#   - **Category**: Category of the product (e.g., Electronics, Clothing, Machinery).
#   - **Port**: Port of entry or departure.
#   - **Customs_Code**: Customs or HS code for product classification.
#   - **Weight**: Weight of the product in kilograms.
#   - **Shipping_Method**: Method used for shipping (e.g., Air, Sea, Land).
#   - **Supplier**: Name of the supplier or manufacturer.
#   - **Customer**: Name of the customer or recipient.
#   - **Invoice_Number**: Unique invoice number for the transaction.
#   - **Payment_Terms**: Terms of payment (e.g., Net 30, Net 60, Cash on Delivery).
#
# - **Data Type**: Since the dataset contains multiple entities (countries) and records data over time, this is an example of Panel Data (also called longitudinal data).
#
# - **Data Variables**:
#   - **All non-null Variables**
#     - **Numbers**:
#       - Integer Variables: 3 (Quantity, Customs_Code, Invoice_Number)
#       - Float (Decimal) Variables: 2 (Value, Weight)
#     - **Text**: 9 (Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customer, Payment_Terms)
#     - **DateTime**: 1 (Date)
#
# ---
#
# ### **3. Data Sampling**
# From the dataset containing 15,000 values, a sample of 5001 entries was taken. The dataset sample (now referred to as `ma24_sample`) was taken into account for further exploration.
#
# - **Data Variables**:
#   - **Index Variables**: 'Transaction_ID', 'Invoice_Number'
#   - **Categorical Variables**:
#     - Nominal Variables: Country, Product, Import_Export, Category, Port, Shipping_Method, Supplier, Customs_Code, Customer
#     - Ordinal Variable: Payment_Terms
#   - **Non-Categorical Variables**: Quantity, Value, and Weight
#
# ---
#
# ### **4. Project Objectives**
# - Classification of Dataset into {Segments | Clusters | Classes} using Supervised Learning Classification Algorithms
# - Identification of {Important | Contributing | Significant} Variables or Features and their Thresholds for Classification
# - Determination of an appropriate Classification Model based on Performance Metrics
#
#
# ---
#
# ### **5. Exploratory Data Analysis**
# #### **5.1. Data Preprocessing:**
# - The data has no missing values, hence no missing data treatment was performed.
# - For Encoding, **Ordinal Encoder** was used.
# - For Scaling, **Min-Max Scaler** was used.
#
# #### **5.2. Descriptive Statistics**
# - **Non-Categorical Variables**:
#   - Measures of Central Tendency: Minimum, Maximum, Mean, Median, Mode, Percentile
#   - Measures of Dispersion: Range, Standard Deviation, Skewness, Kurtosis, Correlation (Matrix)
#   - Composite Measure: Coefficient of Variation, Confidence Interval
#
# - **Categorical Variables**:
#   - Count, Frequency, Proportion, Minimum, Maximum, Mode, Rank
#
# #### **5.3. Data Visualization**
# - Various subplots were used such as Bar, Heatmaps, Histograms, and Correlation Matrices.
#
# #### **5.4. Inferential Statistics**
# - **Categorical Variable** (Nominal | Ordinal):
#   - Test of Homogeneity (Chi-sq)
# - **Non-Categorical Variable**:
#   - Test of Normality (Shapiro-Wilk, Kolmogorov-Smirnov, Anderson-Darling, Jarque-Bera)
#   - Test of Correlation (t)
#
# #### **5.5. Machine Learning Models**
#
# - **Logistic Regression (LR)**:
#   Logistic regression is a classification algorithm that models the probability of a binary outcome based on one or more predictor variables using a logistic function.
#
# - **Support Vector Machines (SVM)**:
#   SVM finds a hyperplane that best separates the data into classes by maximizing the margin between the closest points of the classes (support vectors).
#
# - **Stochastic Gradient Descent (SGD)**:
#   An iterative optimization algorithm used for minimizing loss functions in linear classifiers and regressors, particularly useful for large datasets.
#
# - **Decision Trees**:
#   A tree-based algorithm where each internal node represents a decision on a feature, each leaf node represents an outcome, and paths from root to leaf represent classification rules.
#
# - **K-Nearest Neighbors (KNN)**:
#   A lazy learning algorithm that classifies a data point based on the majority class of its k-nearest neighbors in the feature space.
#
# - **Naive Bayes (NB)**:
#   A probabilistic classifier based on Bayes' theorem, assuming strong independence between features.
#
# - **Bagging (Bootstrap Aggregating)**:
#   Combines predictions from multiple models (e.g., Random Forest) to reduce variance and improve accuracy.
#
# - **Boosting**:
#   Combines weak learners sequentially to form a strong learner by minimizing errors iteratively (e.g., Extreme Gradient Boosting - XGBoost).
#
# #### **5.6. Model Performance Metrics**
#
# - **Confusion Matrix**:
#   - Sensitivity (Recall): True Positive Rate
#   - Specificity: True Negative Rate
#   - Accuracy: Overall correctness
#   - Precision: Positive Predictive Value
#   - F1-Score: Harmonic mean of Precision and Recall
#   - AUC: Area Under the ROC Curve
#
# - **K-Fold Cross-Validation**: Splits data into k subsets; trains on k-1 and tests on the remaining one iteratively to ensure robust performance evaluation.
#
# - **Model Run Statistics**:
#   - Time Taken
#   - Memory Used
#   - Inherent Complexity
# ---
#
#
# ### **6. Observations and Findings**
#
# #### **6.1. Nature of Data**
# - **Missing Data**: The dataset contained no missing values.
# - **Non-Numeric Categorical Data**: Categorical variables (e.g., Country, Product) were encoded using ordinal encoding.
# - **Scales and Outliers**:
#   - Non-categorical numeric data (Quantity, Value, Weight) were scaled using Min-Max scaling.
#   - Box plots revealed potential outliers, but they were not removed as they might hold valuable information.
#
# #### **6.2. Supervised Machine Learning**
#
#
#
#
# 1. **Logistic Regression (LR) vs. Support Vector Machine (SVM)**
#
#    - *Performance Metrics*:
#
#      - LR Accuracy: 33.71%, SVM Accuracy: 33.84%
#
#      - Both models showed poor performance overall, with SVM slightly outperforming LR in accuracy.
#
#    - *Run Statistics*:
#
#      - Logistic Regression was faster (0.02 seconds) compared to SVM (0.97 seconds).
#
#      - SVM had slightly lower memory usage (0.27 MB vs. 0.34 MB for LR).
#
#    - *Conclusion*:
#
#      While SVM has a marginal accuracy advantage, Logistic Regression is preferred for its faster runtime and simplicity, especially for datasets where interpretability and time are critical.
#
#
#
# 2. **Decision Tree (DT) vs. K-Nearest Neighbors (KNN)**
#
#    - *Performance Metrics*:
#
#      - DT Accuracy: 34.64%, KNN Accuracy: 34.11%.
#
#      - DT slightly outperformed KNN in accuracy and consistency across classes.
#
#    - *Run Statistics*:
#
#      - KNN was significantly faster (0.0072 seconds) compared to DT (0.0415 seconds).
#
#      - Memory usage was comparable for both models.
#
#    - *Conclusion*:
#
#      Decision Tree is preferred for its higher accuracy and interpretability, while KNN may be suitable for scenarios prioritizing runtime.
#
#
#
# 3. **Logistic Regression (LR) vs. Decision Tree (DT)**
#
#    - *Performance Metrics*:
#
#      - LR Accuracy: 33.71%, DT Accuracy: 34.64%.
#
#      - DT showed slightly better accuracy and more balanced performance across classes.
#
#    - *Run Statistics*:
#
#      - LR was faster (0.02 seconds) compared to DT (0.0415 seconds).
#
#      - Both models had similar memory usage.
#
#    - *Conclusion*:
#
#      Decision Tree is favored due to better accuracy, while Logistic Regression remains a viable option for faster computations and interpretability.
#
#
#
# 4. **Decision Tree (DT) vs. Random Forest (RF)**
#
#    - *Performance Metrics*:
#
#      - DT Accuracy: 34.64%, RF Accuracy: 34.57%.
#
#      - Both models performed similarly, with DT showing marginally higher accuracy.
#
#    - *Run Statistics*:
#
#      - DT was significantly faster (0.0415 seconds) compared to RF (1.49 seconds).
#
#      - RF consumed more memory (0.46 MB vs. 0.23 MB for DT).
#
#    - *Conclusion*:
#
#      Decision Tree is preferred for faster training, while Random Forest may be more effective for larger, more complex datasets.
#
#
#
# ---
#
#
#
# #### **Cross-Validation of Results and Performance**
#
#
#
# 1. **Logistic Regression**:
#
#    - Mean Cross-Validation Accuracy: 33.03%
#
#    - Test Set Accuracy: 36.44%
#
#    - Observations:
#
#      - Struggles with class imbalance, especially for Class 1 (0% recall).
#
#      - Shows good recall for Class 2 (77%), indicating potential in capturing patterns for specific classes.
#
#
#
# 2. **Support Vector Machine (SVM)**:
#
#    - Mean Cross-Validation Accuracy: 33.09%
#
#    - Test Set Accuracy: 34.24%
#
#    - Observations:
#
#      - Strong bias towards predicting Class 2, achieving perfect recall (100%) but failing completely for Classes 0 and 1.
#
#
#
# 3. **Decision Tree (DT)**:
#
#    - Mean Cross-Validation Accuracy: 34.64%
#
#    - Test Set Accuracy: 35.00%
#
#    - Observations:
#
#      - Consistent performance across classes, with slight improvements in precision, recall, and F1-score for Class 2.
#
#      - Handles non-linear relationships better than LR and SVM.
#
#
#
# 4. **Random Forest (RF)**:
#
#    - Mean Cross-Validation Accuracy: 34.57%
#
#    - Test Set Accuracy: 34.58%
#
#    - Observations:
#
#      - Similar performance to DT but higher memory usage and runtime, making it less practical for this dataset.
#
# ### **7. Managerial Insights and Recommendations**
#
# #### **7.1. Preprocessing of Data**
# - **Missing Data**: No specific treatment is necessary due to the absence of missing data.
# - **Encoding**: Ordinal encoding proved effective for categorical variables.
# - **Scaling**: Min-Max scaling was appropriate to address potential scale differences.
# - **Data Split**: A **70:30 split** for training and testing sets would be appropriate for future supervised learning tasks.
#
# #### **7.2. Supervised Machine Learning**
#
#
# #### **Inference regarding the Purpose of Classification**
# The purpose of the classification is to identify patterns in the data and accurately assign instances to predefined classes. However, all models struggled with poor overall accuracy, suggesting challenges such as class imbalance, insufficient data quality, or lack of relevant features. Improving these areas is critical for achieving meaningful insights.
#
# ---
#
# #### **Logistic Regression (LR)**
# #### **Key Features and Thresholds**
# - Focus on highly correlated features for interpretability, e.g., categorical variables or numeric predictors with strong linear relationships.
# - **Threshold:** Evaluate multiple decision thresholds (e.g., 0.5, 0.6) to balance precision and recall, particularly for underrepresented classes.
#
# #### **Insight on Uniqueness, Usability, and Suitability**
# - **Uniqueness:** Simple and interpretable; suitable for datasets with linearly separable classes.
# - **Usability:** Best for quick preliminary analysis and insights, especially when time and interpretability are critical.
# - **Suitability:** Limited by poor performance in non-linear relationships and class imbalance. More effective with balanced and linearly distributed datasets.
#
# ---
#
# #### **Support Vector Machine (SVM)**
# #### **Key Features and Thresholds**
# - Focus on features that enhance separability between classes in a high-dimensional space.
# - **Threshold:** Use a soft margin for hyperparameter tuning to balance precision and recall for minority classes.
#
# #### **Insight on Uniqueness, Usability, and Suitability**
# - **Uniqueness:** Excellent at capturing complex decision boundaries, especially with kernel tricks for non-linear relationships.
# - **Usability:** Less interpretable and computationally expensive; more suited to small, high-dimensional datasets.
# - **Suitability:** Performs poorly on imbalanced datasets. Best for situations where capturing subtle patterns is essential.
#
# ---
#
# #### **Decision Tree (DT)**
# #### **Key Features and Thresholds**
# - Select features with high information gain or Gini index for splitting nodes.
# - **Threshold:** Adjust tree depth to avoid overfitting while maintaining interpretability (e.g., max depth of 5).
#
# #### **Insight on Uniqueness, Usability, and Suitability**
# - **Uniqueness:** Provides interpretable, tree-structured decisions, capturing non-linear relationships effectively.
# - **Usability:** Easy to visualize and explain, making it useful for decision-making.
# - **Suitability:** Suitable for moderately complex datasets but prone to overfitting on small datasets. Effective for balanced and moderately imbalanced data.
#
# ---
#
# #### **Random Forest (RF)**
# #### **Key Features and Thresholds**
# - Use ensemble averaging to improve predictive accuracy and reduce variance.
# - **Threshold:** Focus on selecting the optimal number of trees (e.g., 50–100) and features per split for performance without excessive resource consumption.
#
# #### **Insight on Uniqueness, Usability, and Suitability**
# - **Uniqueness:** Combines multiple decision trees to improve stability and generalization, reducing overfitting compared to DT.
# - **Usability:** Higher computational cost and memory usage compared to DT but handles noisy and imbalanced data better.
# - **Suitability:** Ideal for larger datasets with complex relationships, where interpretability is less critical than predictive accuracy.
#
# ---
#
# ### **Recommendations for Managerial Actions**
# 1. **Data Quality and Balance:**
#    - Address class imbalance and improve feature engineering to enhance model performance.
#    - Consider oversampling, undersampling, or using class-weight adjustments.
#
# 2. **Model Selection:**
#    - **Logistic Regression** for fast, interpretable results where linear relationships dominate.
#    - **Decision Tree** for interpretable, non-linear modeling of moderately complex data.
#    - **Support Vector Machine** when high-dimensional data and non-linear patterns are present but computational efficiency is secondary.
#    - **Random Forest** for robust predictions in large, complex datasets.
#
# 3. **Operational Use:**
#    - Select models based on the trade-off between accuracy, runtime, and interpretability, aligning with project objectives and data constraints.
#
#
# ---
# ### **Identification of Important Variables or Features and Their Thresholds**
#
# #### **1. Key Features Identified from Multiple Models**
# Analyzing outputs from Decision Tree, Random Forest, XGBoost, KNN, Naive Bayes, and Logistic Regression reveals crucial insights into features influencing classification or clustering. Despite moderate accuracy across models, certain variables consistently emerge as significant:
#
# - **Country**
#   - Strongly correlates with trade patterns and economic agreements. Specific countries often dominate imports or exports in particular categories.
#   - **Thresholds**: Major trade partners (e.g., based on transaction counts or values) often form distinct groups influencing cluster formation.
#
# - **Product**
#   - Plays a pivotal role due to trade specialization, such as Electronics and Machinery versus Clothing.
#   - **Thresholds**: Products with high weights or values tend to indicate distinct classes or clusters.
#
# - **Import_Export**
#   - Differentiates transaction types and highlights trade flow distinctions.
#   - **Thresholds**: Exports are generally associated with higher-value products compared to imports in this dataset.
#
# - **Quantity, Value, and Total_Value**
#   - High numerical correlation with trade significance, particularly in models like Decision Tree and Random Forest.
#   - **Thresholds**:
#     - **Quantity**: Higher quantities are linked to lower-value items like raw materials or bulk goods.
#     - **Value**: Higher-value products cluster separately due to their economic significance.
#
# - **Weight**
#   - Critical for clustering based on shipping and logistics costs.
#   - **Thresholds**: Lightweight, high-value items (e.g., electronics) cluster distinctly from heavy, low-value items (e.g., raw metals).
#
# - **Shipping_Method**
#   - Reflects trade-specific preferences, such as air for lightweight, high-value items versus sea or land for bulk or low-value goods.
#   - **Thresholds**: Specific clusters align with shipping modes, such as air freight for electronics.
#
# - **Port**
#   - Ports often specialize in handling certain categories or trade flows.
#   - **Thresholds**: High-traffic ports typically align with distinct clusters.
#
# - **Customs_Code**
#   - Provides a categorical classification of goods, significantly impacting model performance.
#   - **Thresholds**: HS codes differentiate goods by economic sector or trade priority.
#
# ---
#
# #### **2. Model-Specific Observations and Insights**
#
# #### Decision Tree
# - **Accuracy**: 34.6% (low).
# - **Key Variables**: Country, Product, Quantity, and Value consistently influence tree splits.
# - **Misclassifications**:
#   - Significant confusion between Cluster 0 and Cluster 1.
#   - Slightly better precision, recall, and F1-score for Class 2.0, indicating stronger performance in distinguishing specific clusters.
# - **Thresholds**:
#   - Products with higher Value and lower Weight are more accurately identified.
#   - Quantity thresholds help differentiate bulk from specialized goods.
#
# #### Random Forest
# - **Key Variables**: Similar to Decision Tree, with enhanced handling of non-linear relationships.
# - **Insights**:
#   - Features like Port and Customs_Code significantly influence predictions due to ensemble averaging.
#   - Suggested thresholds include grouping Ports by transaction volume.
#
# #### XGBoost
# - **Accuracy**: 33.24% (low).
# - **Key Variables**: Product, Country, and Value are prominent based on feature importance scores.
# - **Insights**:
#   - Performance suffers from imbalanced data. Adjusting thresholds for major features like Value or using sampling techniques could improve results.
#
# #### KNN
# - **Accuracy**: 34.11% (low).
# - **Key Variables**: Quantity and Weight, as KNN relies heavily on distance-based relationships.
# - **Insights**:
#   - Normalizing data could enhance clustering based on these variables.
#
# #### Naive Bayes
# - **Accuracy**: 33.77% (low).
# - **Key Variables**: Import_Export, Customs_Code, and Shipping_Method.
# - **Insights**:
#   - Assumes feature independence, yet categorical variables like Import_Export and Customs_Code drive predictions.
#
# #### Logistic Regression
# - **Accuracy**: 33.71% (low).
# - **Key Variables**: Country, Product, and Shipping_Method.
# - **Insights**:
#   - Struggles significantly with Cluster 1 due to class imbalance or overlapping data.
#   - Refining thresholds for categorical features like Shipping_Method may help separate clusters.

# %% [markdown]
# ##**Project Information and Analysis**

# %%
# Import Relevant Python Libraries

from io import StringIO
import requests
import pandas as pd
import statsmodels.formula.api as sm
from scipy.stats import chi2_contingency
from scipy.stats import shapiro, kstest, anderson, jarque_bera
from sklearn.decomposition import PCA
from sklearn.cluster import KMeans, DBSCAN, Birch
from scipy.cluster.hierarchy import dendrogram, linkage
import statsmodels.stats.descriptivestats as dstats
import numpy as np  # For Data Manipulation
from sklearn.preprocessing import LabelEncoder, OrdinalEncoder  # For Encoding Categorical Data [Nominal | Ordinal]
from sklearn.impute import SimpleImputer, KNNImputer  # For Imputation of Missing Data
from sklearn.preprocessing import StandardScaler, MinMaxScaler, RobustScaler  # For Rescaling Data
from sklearn.model_selection import train_test_split  # For Splitting Data into Training & Testing Sets
import matplotlib.pyplot as plt
import seaborn as sns  # For Data Visualization
import scipy.cluster.hierarchy as sch  # For Hierarchical Clustering
from sklearn.cluster import AgglomerativeClustering as agclus, KMeans as kmclus  # For Agglomerative & K-Means Clustering
from sklearn.metrics import silhouette_score,davies_bouldin_score  # For Clustering Model Evaluation
import statsmodels.api as sm
from sklearn import metrics
import scipy.stats as stats
import statsmodels.stats.multicomp as multi
import warnings
from sklearn.tree import DecisionTreeClassifier
from sklearn.metrics import classification_report, accuracy_score, confusion_matrix
from sklearn.linear_model import LogisticRegression
from sklearn.ensemble import RandomForestClassifier,GradientBoostingClassifier
from sklearn.model_selection import KFold, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, accuracy_score



warnings.filterwarnings('ignore')

# %%
# Replace with your actual file ID
file_id = '12rprtR_mvX1834zXTGPPo0iF4MZM0fcH'

# Construct the URL
url = f'https://drive.google.com/uc?id={file_id}'  #using f-string (format string)

# Fetch the data using requests
response = requests.get(url)
response.raise_for_status()  # Raise an exception for bad responses

# Read the data into a pandas DataFrame using StringIO
ma24_df = pd.read_csv(StringIO(response.text))

# %%
# Data Dimensions
print("The dimensions of the data is: ",ma24_df.shape)
# Out:
# The dimensions of the data is:  (15000, 16)

# %%
# Data Variable Type
ma24_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 15000 entries, 0 to 14999
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   15000 non-null  object
#  1   Country          15000 non-null  object
#  2   Product          15000 non-null  object
#  3   Import_Export    15000 non-null  object
#  4   Quantity         15000 non-null  int64
#  5   Value            15000 non-null  float64
#  6   Date             15000 non-null  object
#  7   Category         15000 non-null  object
#  8   Port             15000 non-null  object
#  9   Customs_Code     15000 non-null  int64
#  10  Weight           15000 non-null  float64
#  11  Shipping_Method  15000 non-null  object
#  12  Supplier         15000 non-null  object
#  13  Customer         15000 non-null  object
#  14  Invoice_Number   15000 non-null  int64
#  15  Payment_Terms    15000 non-null  object
# ...

# %%
# Bifurcating the Variables into Index, Categorical (Nominal, Ordinal) and Non-Categorical Variables

ma24_index_vars=['Transaction_ID','Invoice_Number']
ma24_nominal_vars=[ 'Country','Product','Import_Export','Category','Port','Shipping_Method','Supplier','Customer','Customs_Code']
ma24_ordinal_vars=['Payment_Terms']

ma24_cat_vars= ma24_nominal_vars + ma24_ordinal_vars
ma24_non_cat_vars=['Quantity','Value','Weight']

# %% [markdown]
# ## **Taking a Unique Sample of 5001 Records**

# %%
ma24_sample = pd.DataFrame.sample(ma24_df, n=5001, random_state=55024 ,ignore_index=False)
# Displaying the Dimensions of Sample Data.
ma24_sample.shape
# Out:
# (5001, 16)

# %% [markdown]
# ## **Data Pre-Processing**

# %%
ma24_sample.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 5001 entries, 1577 to 4089
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Transaction_ID   5001 non-null   object
#  1   Country          5001 non-null   object
#  2   Product          5001 non-null   object
#  3   Import_Export    5001 non-null   object
#  4   Quantity         5001 non-null   int64
#  5   Value            5001 non-null   float64
#  6   Date             5001 non-null   object
#  7   Category         5001 non-null   object
#  8   Port             5001 non-null   object
#  9   Customs_Code     5001 non-null   int64
#  10  Weight           5001 non-null   float64
#  11  Shipping_Method  5001 non-null   object
#  12  Supplier         5001 non-null   object
#  13  Customer         5001 non-null   object
#  14  Invoice_Number   5001 non-null   int64
#  15  Payment_Terms    5001 non-null   object
# dtypes: float64(2), int64(3), object(11)
# ...

# %%
# Check for missing values

ma24_sample.isnull().sum(axis=1)
# Out:
# 1577     0
# 7090     0
# 12020    0
# 13948    0
# 14340    0
#         ..
# 1035     0
# 14801    0
# 1955     0
# 13091    0
# 4089     0
# Length: 5001, dtype: int64

# %% [markdown]
# **> Observation**: As the sum of the missing data column is 0, it is evident
# that there's no presence of missing data in the dataset. So the process of missing data treatment is skipped.

# %%
# Encoding

ma24_oe = OrdinalEncoder()
ma24_categorical_cols = ma24_sample[ma24_cat_vars]
ma24_oe_fit = ma24_oe.fit_transform(ma24_categorical_cols)
ma24_encoded = pd.DataFrame(ma24_oe_fit, columns=ma24_cat_vars)
ma24_encoded.head()
# Out:
#    Country  Product  Import_Export  Category    Port  Shipping_Method  \
# 0     50.0     67.0            1.0       4.0   328.0              0.0
# 1    159.0    207.0            1.0       0.0  1611.0              2.0
# 2    169.0    470.0            1.0       3.0  3626.0              1.0
# 3     18.0    450.0            0.0       0.0  3807.0              0.0
# 4    118.0      6.0            0.0       4.0   389.0              1.0
#
#    Supplier  Customer  Customs_Code  Payment_Terms
# 0     538.0    4093.0        3336.0            0.0
# 1    1641.0    4139.0         275.0            3.0
# 2    1751.0    1994.0         323.0            3.0
# 3    3362.0    2180.0         643.0            3.0
# 4    4024.0     602.0        1188.0            2.0

# %%
#Scaling

ma24_scaler = MinMaxScaler()
ma24_scaled_data = ma24_scaler.fit_transform(ma24_sample[ma24_non_cat_vars])
ma24_scaled = pd.DataFrame(ma24_scaled_data, columns=ma24_non_cat_vars)
ma24_scaled.head()
# Out:
#    Quantity     Value    Weight
# 0  0.189214  0.987820  0.323997
# 1  0.598059  0.241845  0.772252
# 2  0.229037  0.455665  0.933215
# 3  0.957775  0.598224  0.338092
# 4  0.521613  0.083601  0.384026

# %%
# The pre-processed Dataset

ma24_processed = pd.concat([ma24_scaled, ma24_encoded], axis=1)
ma24_processed.head()

ma24_sample = ma24_processed
ma24_sample.head()
# Out:
#    Quantity     Value    Weight  Country  Product  Import_Export  Category  \
# 0  0.189214  0.987820  0.323997     50.0     67.0            1.0       4.0
# 1  0.598059  0.241845  0.772252    159.0    207.0            1.0       0.0
# 2  0.229037  0.455665  0.933215    169.0    470.0            1.0       3.0
# 3  0.957775  0.598224  0.338092     18.0    450.0            0.0       0.0
# 4  0.521613  0.083601  0.384026    118.0      6.0            0.0       4.0
#
#      Port  Shipping_Method  Supplier  Customer  Customs_Code  Payment_Terms
# 0   328.0              0.0     538.0    4093.0        3336.0            0.0
# 1  1611.0              2.0    1641.0    4139.0         275.0            3.0
# 2  3626.0              1.0    1751.0    1994.0         323.0            3.0
# 3  3807.0              0.0    3362.0    2180.0         643.0            3.0
# 4   389.0              1.0    4024.0     602.0        1188.0            2.0

# %% [markdown]
# ## **Descriptive Statistics**
#
# ### **1. Non-Categorical Variables**

# %%
ma24_sample[ma24_non_cat_vars].describe()
# Out:
#           Quantity        Value       Weight
# count  5001.000000  5001.000000  5001.000000
# mean      0.498036     0.501559     0.492472
# std       0.284672     0.288226     0.289802
# min       0.000000     0.000000     0.000000
# 25%       0.255453     0.255067     0.242343
# 50%       0.492195     0.503997     0.481171
# 75%       0.745848     0.748879     0.745205
# max       1.000000     1.000000     1.000000

# %% [markdown]
# #### **> Observations:**
#
# **Central Tendency:** The mean values for Quantity, Value, and Weight are all centered around 0.5, indicating a balanced distribution after Min-Max scaling.
#
# **Similar Variability:** The standard deviation for all three variables is around 0.29, signifying moderate data dispersion.
#
# **Scaled Data:** The minimum and maximum values of 0 and 1 respectively confirm the data has been normalized using Min-Max scaling.

# %%
def summarize_numerical(my_sample, variables):
    summary = {}

    for col in variables:
        if col in ma24_sample[ma24_non_cat_vars]:  # Check if the column exists in the DataFrame
            summary[col] = {
                'Mode': my_sample[col].mode()[0],
                'Range': my_sample[col].max() - my_sample[col].min(),
                'Skewness': my_sample[col].skew() ,
                'Kurtosis': my_sample[col].kurtosis()
            }
    return summary

# %%
summary_stats = summarize_numerical(ma24_sample,ma24_non_cat_vars)
summary_df = pd.DataFrame.from_dict(summary_stats, orient='index')
summary_df
# Out:
#               Mode  Range  Skewness  Kurtosis
# Quantity  0.148489    1.0  0.022847 -1.167911
# Value     0.096625    1.0 -0.002597 -1.178109
# Weight    0.006080    1.0  0.056161 -1.197273

# %% [markdown]
# #### **> Observations:**
#
# **Range:**
# All three variables (Quantity, Value, Weight) exhibit a range of 1.0. This confirms that Min-Max scaling has effectively normalized the data to cover the entire range from 0 to 1, maximizing variability utilization.
#
# **Skewness:**
# Skewness values for Quantity, Value, and Weight are close to zero. This indicates near-symmetric distributions, suggesting a balanced frequency of observations on both sides of the average, with a potential slight positive skew.
#
# **Kurtosis:**
# Kurtosis values for all three variables are negative. This implies platykurtic distributions, meaning the data has fewer extreme values or outliers compared to a normal distribution, resulting in a flatter peak.

# %%
# Coefficient of Variation
def coefficient_of_variation(data):
    mean = data.mean()
    std = data.std()
    cv = (std / mean) * 100
    return cv

cv_results = {}

for col in ma24_non_cat_vars:
    cv_results[col] = coefficient_of_variation(ma24_sample[col])

# Display the results
print("Coefficient of Variation (%):")
for col, cv in cv_results.items():
    print(f"{col}: {cv:.2f}%")
# Out:
# Coefficient of Variation (%):
# Quantity: 57.16%
# Value: 57.47%
# Weight: 58.85%

# %% [markdown]
# ####**> Observations:**
#
# **Quantity:**
#
# - Quantity has a CV of 57.16%.
# - This indicates moderate variability or dispersion in the quantity of products traded relative to the mean quantity.
#
# **Value:**
#
# - Value shows a CV of 57.47%.
# - This suggests a moderate level of variability in the monetary value of transactions compared to the average transaction value.
#
# **Weight:**
#
# - Weight exhibits a CV of 58.85%.
# - This signifies moderate variability in the weight of products traded relative to the mean weight, potentially reflecting product diversity.

# %%
# Confidence Interval for the Mean
def confidence_interval(data, confidence=0.95):
    mean = data.mean()
    std = data.std()
    n = len(data)
    z = stats.norm.ppf(1 - (1 - confidence) / 2)  # z-score for 95% CI
    margin_of_error = z * (std / np.sqrt(n))
    lower_bound = mean - margin_of_error
    upper_bound = mean + margin_of_error
    return (lower_bound, upper_bound)

ci_results = {}
for col in ma24_non_cat_vars:
    ci_results[col] = confidence_interval(ma24_sample[col])


print("\nConfidence Intervals (95%):")
for col, ci in ci_results.items():
    print(f"{col}: {ci[0]:.2f} to {ci[1]:.2f}")
# Out:
# Confidence Intervals (95%):
# Quantity: 0.49 to 0.51
# Value: 0.49 to 0.51
# Weight: 0.48 to 0.50

# %% [markdown]
# ####**> Observations:**
#
# **Quantity:**
#
# - The 95% CI for Quantity is 0.49 to 0.51.
# - This narrow interval suggests high precision in estimating the true population mean of Quantity, indicating a likely centralized distribution around 0.5.
#
# **Value:**
#
# - The 95% CI for Value is 0.49 to 0.51.
# - This slightly wider interval compared to Quantity implies a marginally higher uncertainty in estimating the population mean of Value, but still indicates a relatively centralized distribution.
#
# **Weight:**
#
# - The 95% CI for Weight is 0.48 to 0.50.
# - Similar to Value, this interval reflects moderate certainty in estimating the population mean of Weight and a likely centralized distribution around 0.5.

# %%
correlation_data = ma24_sample[ma24_non_cat_vars]
correlation_matrix = correlation_data.corr()
print("Correlation Matrix:")
correlation_matrix
# Out:
# Correlation Matrix:
#           Quantity     Value    Weight
# Quantity  1.000000 -0.017941 -0.007780
# Value    -0.017941  1.000000  0.001574
# Weight   -0.007780  0.001574  1.000000

# %%
plt.figure(figsize=(8, 5))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)
plt.title('Correlation Matrix Heatmap')
plt.show()

# %% [markdown]
# ####**> Observations:**
#
# **Quantity and Value:**
# The correlation coefficient is approximately -0.018, indicating a very weak negative relationship. This means that as the quantity increases, the value tends to decrease slightly, but the relationship is not statistically significant.
#
# **Quantity and Weight:**
# The correlation coefficient is approximately -0.0078, showing a very weak negative relationship. This suggests that as the quantity increases, the weight tends to decrease slightly, but the relationship is not statistically significant.
#
# **Value and Weight:**
#  The correlation coefficient is approximately 0.0016, signifying an almost non-existent positive relationship. This implies that there is a negligible positive association between value and weight.

# %% [markdown]
# ### **2. Categorical Variables**

# %%
# Categorical Data

def ma24_categorical_summary(df, cat_cols):
    summary = {}
    for col in cat_cols:
        if col in df.columns:
            summary[col] = {
                'Count': df[col].count(),
                'Minimum': df[col].min(),
                'Maximum': df[col].max(),
                'Mode': df[col].mode().iloc[0],
            }
    return summary

ma24_categorical_summaries = ma24_categorical_summary(ma24_sample, ma24_cat_vars)

for col, stats in ma24_categorical_summaries.items():
    print(f"Summary for {col}:")
    for stat_name, stat_value in stats.items():
        print(f"  {stat_name}: {stat_value}")
    print("-" * 20)  # separator
# Out:
# Summary for Country:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 242.0
#   Mode: 49.0
# --------------------
# Summary for Product:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 967.0
#   Mode: 967.0
# --------------------
# Summary for Import_Export:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 1.0
#   Mode: 1.0
# --------------------
# Summary for Category:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4.0
#   Mode: 1.0
# --------------------
# Summary for Port:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4289.0
#   Mode: 2846.0
# --------------------
# Summary for Shipping_Method:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 2.0
#   Mode: 0.0
# --------------------
# Summary for Supplier:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4580.0
#   Mode: 428.0
# --------------------
# Summary for Customer:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4835.0
#   Mode: 3344.0
# --------------------
# Summary for Customs_Code:
#   Count: 5001
#   Minimum: 0.0
#   Maximum: 4990.0
# ...

# %% [markdown]
# ## **Data Visualization**

# %%
# Box plots for non-categorical variables

plt.figure(figsize=(15, 10))
for i, col in enumerate(ma24_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.boxplot(y=ma24_sample[col])
    plt.title(f'Box Plot of {col}')
plt.tight_layout()
plt.show()

# %%
# Histograms with KDE for distribution visualization
plt.figure(figsize=(15, 10))
for i, col in enumerate(ma24_non_cat_vars):
    plt.subplot(2, 3, i + 1)
    sns.histplot(ma24_sample[col], kde=True)
    plt.title(f'Distribution of {col}')
plt.tight_layout()
plt.show()

# %%
# Violin Plot

sns.violinplot(x='Category', y='Quantity', data=ma24_sample)
plt.title('Distribution of Quantity across Categories')
plt.show()

# %% [markdown]
# ## **Inferential Statistics**

# %%
# Test of Homogeneity {Chi-sq} on categorical data

ma24_contingency_table = pd.crosstab(ma24_sample['Import_Export'], ma24_sample['Category'])

# Perform the Chi-square test
chi2, p, dof, expected = chi2_contingency(ma24_contingency_table)

print(f"Chi-square statistic: {chi2}")
print(f"P-value: {p}")
print(f"Degrees of freedom: {dof}")
print("Expected frequencies:")
print(expected)

# Interpret the results
ma24_alpha = 0.05  # Significance level

if p < ma24_alpha:
    print("Reject the null hypothesis: There is a significant association between the two categorical variables.")
else:
    print("There is no significant association between the two categorical variables.")
# Out:
# Chi-square statistic: 4.003698208739155
# P-value: 0.405505582950909
# Degrees of freedom: 4
# Expected frequencies:
# [[515.36392721 519.35512897 505.88482304 460.98380324 493.41231754]
#  [517.63607279 521.64487103 508.11517696 463.01619676 495.58768246]]
# There is no significant association between the two categorical variables.

# %%
# Test of Normality {Shapiro-Wilk | Kolmogorov-Smirnov | Anderson-Darling | Jarque-Bera

def normality_tests(data):

    ma24_results = {}

    # Shapiro-Wilk test
    shapiro_statistic, shapiro_pvalue = shapiro(data)
    ma24_results["Shapiro-Wilk"] = {"statistic": shapiro_statistic, "p-value": shapiro_pvalue}

    # Kolmogorov-Smirnov test (against a normal distribution)
    ks_statistic, ks_pvalue = kstest(data, 'norm')
    ma24_results["Kolmogorov-Smirnov"] = {"statistic": ks_statistic, "p-value": ks_pvalue}

    # Anderson-Darling test
    anderson_result = anderson(data)
    ma24_results["Anderson-Darling"] = {
        "statistic": anderson_result.statistic,
        "critical_values": anderson_result.critical_values,
        "significance_level": anderson_result.significance_level
    }

    # Jarque-Bera test
    jb_statistic, jb_pvalue = jarque_bera(data)
    ma24_results["Jarque-Bera"] = {"statistic": jb_statistic, "p-value": jb_pvalue}

    return ma24_results

# %%
from scipy import stats

# Test of Correlation (T-test)
def t_test_correlation(data1, data2):
    t_statistic, p_value = stats.ttest_ind(data1, data2)
    return {"t-statistic": t_statistic, "p-value": p_value}

for col in ma24_non_cat_vars:
    print(f"Normality tests for {col}:")
    normality_test_results = normality_tests(ma24_sample[col])
    for test_name, result in normality_test_results.items():
        print(f"  {test_name}: {result}")

    # Example of T-test
    if len(ma24_non_cat_vars) > 1:
        for i in range(len(ma24_non_cat_vars)):
            for j in range(i+1, len(ma24_non_cat_vars)):
                col1, col2 = ma24_non_cat_vars[i], ma24_non_cat_vars[j]
                t_test_result = t_test_correlation(ma24_sample[col1], ma24_sample[col2])
                print(f"T-test Correlation between {col1} and {col2}: {t_test_result}")
    print()
    print('*'*20)
    print()
# Out:
# Normality tests for Quantity:
#   Shapiro-Wilk: {'statistic': 0.9584710574625914, 'p-value': 1.4170786896537184e-35}
#   Kolmogorov-Smirnov: {'statistic': 0.5000794672217869, 'p-value': 0.0}
#   Anderson-Darling: {'statistic': 50.277907831727134, 'critical_values': array([0.576, 0.655, 0.786, 0.917, 1.091]), 'significance_level': array([15. , 10. ,  5. ,  2.5,  1. ])}
#   Jarque-Bera: {'statistic': 284.67727754814956, 'p-value': 1.5244550341786727e-62}
# T-test Correlation between Quantity and Value: {'t-statistic': -0.6150327783706231, 'p-value': 0.538547068409145}
# T-test Correlation between Quantity and Weight: {'t-statistic': 0.9684537803403974, 'p-value': 0.33284121311912085}
# T-test Correlation between Value and Weight: {'t-statistic': 1.5721178376820821, 'p-value': 0.11595486209783165}
#
# ********************
#
# Normality tests for Value:
#   Shapiro-Wilk: {'statistic': 0.9565281411578583, 'p-value': 3.150609653913455e-36}
# ...

# %% [markdown]
# ## Observations for Normality Tests for Quantity
#
# * **Shapiro-Wilk:** The p-value is extremely low (1.42e-35), strongly rejecting normality for Quantity.
# * **Kolmogorov-Smirnov:** The p-value of 0.0 provides strong evidence against normality for Quantity.
# * **Anderson-Darling:** The high test statistic (50.28) further confirms the non-normality of Quantity.
# * **Jarque-Bera:** The extremely low p-value (1.52e-62) reinforces the rejection of normality for Quantity.
# * **T-test (Quantity vs. Value):** No significant correlation is found between Quantity and Value (p-value: 0.5385).
# * **T-test (Quantity vs. Weight):** No significant correlation is found between Quantity and Weight (p-value: 0.3328).
#
# ## Observations for Normality Tests for Value
#
# * **Shapiro-Wilk:** The extremely low p-value (3.15e-36) strongly indicates that the Value data is not normally distributed.
# * **Kolmogorov-Smirnov:** Similar to Shapiro-Wilk, the p-value of 0.0 leads to a strong rejection of normality for Value.
# * **Anderson-Darling:** The high test statistic (51.64) further supports the rejection of normality for the Value data.
# * **Jarque-Bera:** The extremely low p-value (1.57e-63) provides strong evidence against the normality of the Value data.
# * **T-test (Quantity vs. Value):** There is no statistically significant correlation between Quantity and Value (p-value: 0.5385).
# * **T-test (Value vs. Weight):** There is no statistically significant correlation between Value and Weight (p-value: 0.1160).
#
# ## Observations for Normality Tests for Weight
#
# * **Shapiro-Wilk:** With a p-value of 5.61e-37, the Shapiro-Wilk test strongly rejects normality for Weight.
# * **Kolmogorov-Smirnov:** The p-value of 0.0 provides clear evidence against normality for Weight.
# * **Anderson-Darling:** The high test statistic (56.43) further confirms the non-normality of Weight.
# * **Jarque-Bera:** The extremely low p-value (3.70e-66) reinforces the rejection of normality for Weight.
# * **T-test (Quantity vs. Weight):** There is no statistically significant correlation between Quantity and Weight (p-value: 0.3328).
# * **T-test (Value vs. Weight):** There is no statistically significant correlation between Value and Weight (p-value: 0.1160).
#
# ## Key Takeaways
#
# * **Non-Normality:** All three variables (Quantity, Value, and Weight) show strong evidence of non-normality based on all four normality tests.
# * **Weak Correlations:** Despite non-normality, the T-tests indicate no statistically significant correlations between any pair of variables.

# %% [markdown]
# #**Supervised Learning**

# %% [markdown]
# ### **Split into test and train dataset**

# %%
ma24_X = ma24_processed[['Quantity','Weight']]  # Features (excluding 'Cluster')
ma24_y = ma24_processed[['Shipping_Method']]  # Target variable

ma24_X_train, ma24_X_test, ma24_y_train, ma24_y_test = train_test_split(ma24_X, ma24_y, test_size=0.3, random_state=55024)

# Print the shapes of the resulting datasets
print("X_train shape:", ma24_X_train.shape)
print("X_test shape:", ma24_X_test.shape)
print("y_train shape:", ma24_y_train.shape)
print("y_test shape:", ma24_y_test.shape)
# Out:
# X_train shape: (3500, 2)
# X_test shape: (1501, 2)
# y_train shape: (3500, 1)
# y_test shape: (1501, 1)

# %% [markdown]
# ###**> Classification <**
#
# ###**Decision Tree**

# %%
# Initialize the Decision Tree Classifier
ma24_dt_classifier = DecisionTreeClassifier(criterion='gini', random_state=55024)

# Train the model
ma24_dt_classifier.fit(ma24_X_train, ma24_y_train)

# Make predictions on the test set
ma24_y_pred_dt = ma24_dt_classifier.predict(ma24_X_test)

# %%
# Evaluate the model
ma24_accuracy_dt = accuracy_score(ma24_y_test, ma24_y_pred_dt)
print(f"Decision Tree Accuracy: {ma24_accuracy_dt}")
print(classification_report(ma24_y_test, ma24_y_pred_dt))
# Out:
# Decision Tree Accuracy: 0.346435709526982
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.34      0.35       508
#          1.0       0.32      0.32      0.32       479
#          2.0       0.36      0.37      0.37       514
#
#     accuracy                           0.35      1501
#    macro avg       0.35      0.35      0.35      1501
# weighted avg       0.35      0.35      0.35      1501

# %% [markdown]
# ## Decision Tree Model Performance
#
# **Overall Accuracy:**
#
# * The model achieved an accuracy of 0.35 (or 35%). This means the model correctly predicted the class for 35% of the instances in the dataset.
#
# **Class-wise Performance:**
#
# * **Class 0.0:**
#     * Precision: 0.35
#     * Recall: 0.34
#     * F1-score: 0.35
# * **Class 1.0:**
#     * Precision: 0.32
#     * Recall: 0.32
#     * F1-score: 0.32
# * **Class 2.0:**
#     * Precision: 0.36
#     * Recall: 0.37
#     * F1-score: 0.37
#
# **Interpretation:**
#
# * **Precision:** The percentage of correctly predicted instances among all instances predicted as belonging to that class.
# * **Recall:** The percentage of correctly predicted instances among all actual instances of that class.
# * **F1-score:** The harmonic mean of precision and recall, providing a balanced measure of both.
#
# **Macro Average:**
#
# * Precision: 0.35
# * Recall: 0.35
# * F1-score: 0.35
#
# This average considers each class equally, giving an overall view of the model's performance across all classes.
#
# **Weighted Average:**
#
# * Precision: 0.35
# * Recall: 0.35
# * F1-score: 0.35
#
# This average weighs the class-wise metrics by the number of instances in each class, providing a more representative measure of the model's performance on the entire dataset.
#
# **Support:**
#
# * Class 0.0: 508 instances
# * Class 1.0: 479 instances
# * Class 2.0: 514 instances
#
# This indicates the number of samples in each class used for evaluation.
#
# **Overall Observations:**
#
# * The model's accuracy is relatively low, indicating that it may not be very effective in classifying the instances.
# * The performance across classes is fairly consistent, with Class 2.0 showing slightly better results in terms of precision, recall, and F1-score.
# * The macro and weighted averages are similar, suggesting a balanced performance across classes.
#
# **Further Considerations:**
#
# * **Hyperparameter Tuning:** Exploring different hyperparameter settings for the Decision Tree model might improve its performance.
# * **Feature Engineering:** Creating new features or transforming existing ones could potentially enhance the model's ability to learn patterns.
# * **Alternative Models:** Trying other machine learning algorithms (e.g., Random Forest, Support Vector Machines) might yield better results.

# %%
# Confusion matrix

ma24_cm = confusion_matrix(ma24_y_test, ma24_y_pred_dt)

# Plot the confusion matrix using seaborn
plt.figure(figsize=(8, 6))
sns.heatmap(ma24_cm, annot=True, fmt='d', cmap='Blues',
            xticklabels=ma24_dt_classifier.classes_, yticklabels=ma24_dt_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Decision Tree')
plt.show()

# %% [markdown]
# ## Confusion Matrix Analysis
#
# **Overall Performance**
#
# * The diagonal values (True Positives) are relatively low, indicating moderate accuracy in cluster assignments.
# * The off-diagonal values (False Negatives) are significant, showing a substantial amount of misclassification between clusters. This suggests that the Decision Tree model might not be effectively capturing the underlying structure of the data for accurate clustering.
#
# **Cluster-Specific Observations**
#
# * **Cluster 0:**
#     * The model correctly classified 164 instances (True Positives).
#     * It misclassified 174 instances into Cluster 1 and 169 instances into Cluster 2 (False Negatives). This indicates a tendency to confuse Cluster 0 with both Cluster 1 and Cluster 2, with a slightly higher inclination towards misclassification into Cluster 1.
#
# * **Cluster 1:**
#     * The model correctly classified 170 instances (True Positives).
#     * It misclassified 155 instances into Cluster 0 and 155 instances into Cluster 2 (False Negatives). This suggests a relatively balanced misclassification pattern for Cluster 1, with similar tendencies to be confused with both Cluster 0 and Cluster 2.
#
# * **Cluster 2:**
#     * The model correctly classified 189 instances (True Positives).
#     * It misclassified 162 instances into Cluster 0 and 163 instances into Cluster 1 (False Negatives). This reveals a tendency to misclassify Cluster 2 instances into both Cluster 0 and Cluster 1, with a slightly higher inclination towards misclassification into Cluster 0.
#
# **Insights and Further Considerations**
#
# * The confusion matrix provides valuable insights into the types of errors made by the Decision Tree model. This information can be used to identify areas for improvement.
# * Given the low accuracy and significant misclassification, it might be beneficial to explore alternative clustering algorithms (e.g., K-Means, Hierarchical Clustering, DBSCAN) that might be better suited for the data.
# * Feature engineering techniques could also be explored to improve the model's performance. This could involve creating new features or transforming existing ones to better capture the underlying patterns in the data.
# * It's important to consider the specific goals and requirements of the project when interpreting the confusion matrix and evaluating the model's performance.
#
# **Key Takeaway**
#
# The Decision Tree model, based on this confusion matrix, appears to have limitations in accurately clustering the data. Further investigation and exploration of alternative approaches are recommended.
#
# **Note:** This analysis is based on the provided confusion matrix. A more comprehensive evaluation would involve considering other performance metrics (e.g., precision, recall, F1-score) and visualizing the data to gain a deeper understanding of the underlying patterns and relationships.

# %% [markdown]
# ###**K Nearest Neighbours**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.metrics import accuracy_score, classification_report


# 2. Create and train the KNN classifier
knn = KNeighborsClassifier(n_neighbors=5)  # You can adjust the number of neighbors (k)
knn.fit(ma24_X_train, ma24_y_train)

# 3. Make predictions on the test set
y_pred = knn.predict(ma24_X_test)

# 4. Evaluate the model
ma24_accuracy_knn = accuracy_score(ma24_y_test, y_pred)
print(f"Accuracy: {ma24_accuracy_knn}")
print(classification_report(ma24_y_test, y_pred))
# Out:
# Accuracy: 0.34110592938041306
#               precision    recall  f1-score   support
#
#          0.0       0.34      0.51      0.41       508
#          1.0       0.31      0.29      0.30       479
#          2.0       0.38      0.23      0.28       514
#
#     accuracy                           0.34      1501
#    macro avg       0.34      0.34      0.33      1501
# weighted avg       0.35      0.34      0.33      1501

# %% [markdown]
# **Model Performance Analysis**
#
# The model has a low overall accuracy of approximately 34%, indicating that it struggles to correctly classify instances across the different classes.
#
# **Class-wise Performance:**
#
# * **Class 0.0:** This class has a relatively high recall (0.51), meaning the model is good at identifying true instances of this class. However, it has lower precision (0.34), suggesting that a significant portion of the instances predicted as belonging to Class 0.0 are actually from other classes.
#
# * **Class 1.0:** This class shows a more balanced performance with precision (0.31) and recall (0.29) being relatively close.
#
# * **Class 2.0:** This class has the highest precision (0.38), meaning that when the model predicts an instance as belonging to Class 2.0, it is likely to be correct. However, it has the lowest recall (0.23), indicating that the model misses a significant number of actual instances of Class 2.0.
#
# **Macro and Weighted Averages:**
#
# Both the macro and weighted averages of precision, recall, and F1-score are low, further confirming the model's suboptimal performance overall. The macro average treats all classes equally, while the weighted average gives more weight to classes with more instances.
#
# **Overall, the model's performance is not satisfactory.** It struggles to accurately classify instances across all classes, with varying degrees of success for each class. Further analysis and potential improvements, such as hyperparameter tuning or feature engineering, are necessary to enhance the model's performance.

# %% [markdown]
# ### **Naive Bayes (NB)**

# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB  # Or MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, classification_report

# 2. Create and train the Naive Bayes classifier
nb = GaussianNB()  # Choose the appropriate NB type (GaussianNB, MultinomialNB, BernoulliNB)
nb.fit(ma24_X_train, ma24_y_train)

# 3. Make predictions on the test set
ma24_y_pred = nb.predict(ma24_X_test)

# 4. Evaluate the model
ma24_accuracy_nb = accuracy_score(ma24_y_test, ma24_y_pred)
print(f"Accuracy: {ma24_accuracy_nb}")
print(classification_report(ma24_y_test, ma24_y_pred))
# Out:
# Accuracy: 0.33777481678880744
#               precision    recall  f1-score   support
#
#          0.0       0.34      0.89      0.49       508
#          1.0       0.00      0.00      0.00       479
#          2.0       0.32      0.11      0.16       514
#
#     accuracy                           0.34      1501
#    macro avg       0.22      0.33      0.22      1501
# weighted avg       0.22      0.34      0.22      1501

# %% [markdown]
# **Model Performance Analysis**
#
# The model has a low overall accuracy of approximately 34%, indicating that it struggles to correctly classify instances across the different classes.
#
# **Class-wise Performance:**
#
# * **Class 0.0:** This class has a relatively high recall (0.89), meaning the model is good at identifying true instances of this class. However, it has lower precision (0.34), suggesting that a significant portion of the instances predicted as belonging to Class 0.0 are actually from other classes.
#
# * **Class 1.0:** This class exhibits extremely poor performance with precision, recall, and F1-score all being very low (0.00). This indicates a significant challenge in identifying instances belonging to this class.
#
# * **Class 2.0:** This class has the highest precision (0.32), meaning that when the model predicts an instance as belonging to Class 2.0, it is likely to be correct. However, it has a low recall (0.11), indicating that the model misses a significant number of actual instances of Class 2.0.
#
# **Macro and Weighted Averages:**
#
# * The macro average highlights the imbalanced performance, primarily due to the poor results on Class 1.0.
#
# * The weighted average F1-score is low, further confirming the model's suboptimal performance overall.
#
# **Overall, the model's performance is not satisfactory.** It struggles to accurately classify instances across all classes, with varying degrees of success for each class. Further analysis and potential improvements, such as hyperparameter tuning or feature engineering, are necessary to enhance the model's performance.

# %% [markdown]
# ##**Logistic Regression**

# %%
# Initialize the Logistic Regression model
ma24_logreg_classifier = LogisticRegression(random_state=55024)

# Train the model
ma24_logreg_classifier.fit(ma24_X_train, ma24_y_train)

# Make predictions on the test set
ma24_y_pred_logreg = ma24_logreg_classifier.predict(ma24_X_test)

# Evaluate the model
ma24_accuracy_logreg = accuracy_score(ma24_y_test, ma24_y_pred_logreg)
print(f"Logistic Regression Accuracy: {ma24_accuracy_logreg}")
print(classification_report(ma24_y_test, ma24_y_pred_logreg))
# Out:
# Logistic Regression Accuracy: 0.33710859427048634
#               precision    recall  f1-score   support
#
#          0.0       0.34      0.87      0.49       508
#          1.0       0.00      0.00      0.00       479
#          2.0       0.33      0.13      0.18       514
#
#     accuracy                           0.34      1501
#    macro avg       0.22      0.33      0.22      1501
# weighted avg       0.23      0.34      0.23      1501

# %% [markdown]
# **Model Performance Analysis**
#
# The model has a low overall accuracy of approximately 34%, indicating that it struggles to correctly classify instances across the different classes.
#
# **Class-wise Performance:**
#
# * **Class 0.0:** This class has a relatively high recall (0.87), meaning the model is good at identifying true instances of this class. However, it has lower precision (0.34), suggesting that a significant portion of the instances predicted as belonging to Class 0.0 are actually from other classes.
#
# * **Class 1.0:** The model completely fails to identify instances belonging to Class 1.0, as indicated by zero precision, recall, and F1-score. This is a major concern and requires further investigation.
#
# * **Class 2.0:** This class has the highest precision (0.33), meaning that when the model predicts an instance as belonging to Class 2.0, it is likely to be correct. However, it has a low recall (0.13), indicating that the model misses a significant number of actual instances of Class 2.0.
#
# **Macro and Weighted Averages:**
#
# * The macro average highlights the imbalanced performance due to the complete failure on Class 1.0.
#
# * The weighted average precision and F1-score are low, further confirming the model's suboptimal performance overall.
#
# **Overall, the model's performance is not satisfactory.** It struggles to accurately classify instances across all classes, with varying degrees of success for each class. Further analysis and potential improvements, such as hyperparameter tuning or feature engineering, are necessary to enhance the model's performance.

# %%
# Confusion Matrix for Logistic Regression
cm_logreg = confusion_matrix(ma24_y_test, ma24_y_pred_logreg)

# Plot the confusion matrix for Logistic Regression
plt.figure(figsize=(8, 6))
sns.heatmap(cm_logreg, annot=True, fmt='d', cmap='Greens',  # Different colormap
            xticklabels=ma24_logreg_classifier.classes_, yticklabels=ma24_logreg_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Logistic Regression')
plt.show()

# %% [markdown]
# **Confusion Matrix Analysis**
#
# **Overall Performance**
#
# * The diagonal values (True Positives) are relatively low, indicating moderate accuracy in cluster assignments.
# * The off-diagonal values (False Negatives) are significant, showing a substantial amount of misclassification between clusters. This suggests that the Logistic Regression model might not be effectively capturing the underlying structure of the data for accurate clustering.
#
# **Cluster-Specific Observations**
#
# * **Cluster 0:**
#     * The model correctly classified 441 instances (True Positives).
#     * It misclassified 0 instances into Cluster 1 and 67 instances into Cluster 2 (False Negatives). This suggests the model struggles to distinguish Cluster 0 from Cluster 2.
#
# * **Cluster 1:**
#     * The model correctly classified 0 instances (True Positives).
#     * It misclassified 411 instances into Cluster 0 and 68 instances into Cluster 2 (False Negatives). This indicates the model completely fails to identify instances belonging to Cluster 1.
#
# * **Cluster 2:**
#     * The model correctly classified 449 instances (True Positives).
#     * It misclassified 65 instances into Cluster 0 and 0 instances into Cluster 1 (False Negatives). This reveals a tendency to misclassify Cluster 2 instances into Cluster 0.
#
# **Insights and Further Considerations**
#
# * The confusion matrix provides valuable insights into the types of errors made by the Logistic Regression model. This information can be used to identify areas for improvement.
# * Given the low accuracy and significant misclassification, particularly for Cluster 1, it might be beneficial to explore alternative clustering algorithms (e.g., K-Means, Hierarchical Clustering, DBSCAN) that might be better suited for the data.
# * Feature engineering techniques could also be explored to improve the model's performance. This could involve creating new features or transforming existing ones to better capture the underlying patterns in the data.
# * It's important to consider the specific goals and requirements of the project when interpreting the confusion matrix and evaluating the model's suitability for the intended task.
#
# **Key Takeaway**
#
# The Logistic Regression model, based on this confusion matrix, appears to have limitations in accurately clustering the data, especially for Cluster 1. Further investigation and exploration of alternative approaches are recommended.
#
# **Note:** This analysis is based on the provided confusion matrix. A more comprehensive evaluation would involve considering other performance metrics (e.g., precision, recall, F1-score) and visualizing the data to gain a deeper understanding of the underlying patterns and relationships.

# %% [markdown]
# ###**K-Fold Cross Validation for Logistic Regression**

# %%
# Initialize the Logistic Regression model
ma24_logreg_classifier = LogisticRegression(random_state=55024)

# Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55024)

# Perform Cross-Validation
cv_accuracy = cross_val_score(ma24_logreg_classifier, ma24_X_train, ma24_y_train, cv=kfold, scoring='accuracy')

# Output Cross-Validation results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# Train the model on the entire training set (if needed for later use)
ma24_logreg_classifier.fit(ma24_X_train, ma24_y_train)

# Evaluate the model on the test set
ma24_y_pred_logreg = ma24_logreg_classifier.predict(ma24_X_test)
ma24_accuracy_logreg = accuracy_score(ma24_y_test, ma24_y_pred_logreg)
print(f"Logistic Regression Test Set Accuracy: {ma24_accuracy_logreg}")
print(classification_report(ma24_y_test, ma24_y_pred_logreg))
# Out:
# K-Fold Cross-Validation Accuracy Scores:  [0.33285714 0.35428571 0.34142857 0.34571429 0.34285714]
# Mean Accuracy:  0.3434285714285714
# Standard Deviation of Accuracy:  0.0069164105353772525
# Logistic Regression Test Set Accuracy: 0.33710859427048634
#               precision    recall  f1-score   support
#
#          0.0       0.34      0.87      0.49       508
#          1.0       0.00      0.00      0.00       479
#          2.0       0.33      0.13      0.18       514
#
#     accuracy                           0.34      1501
#    macro avg       0.22      0.33      0.22      1501
# weighted avg       0.23      0.34      0.23      1501

# %% [markdown]
# **Observations:**
#
# **Cross-Validation:**
#
# * The K-Fold Cross-Validation Accuracy Scores show some variability, ranging from 0.3328 to 0.3428.
# * The Mean Accuracy across the folds is 0.3434, indicating moderate performance on average.
# * The Standard Deviation of Accuracy (0.0069) suggests a certain level of variability in the model's performance across different folds.
#
# **Test Set Performance:**
#
# * The Test Set Accuracy is 0.3371, slightly higher than the mean cross-validation accuracy. This suggests that the model's performance on unseen data might be slightly better than its average performance during cross-validation.
#
# **Classification Report:**
#
# * **Class 0:** Shows moderate precision (0.40) and recall (0.30), indicating a balance between correctly predicting instances of this class and minimizing false positives.
# * **Class 1:** The model completely fails to identify instances belonging to Class 1, as indicated by zero precision, recall, and F1-score. This is a major concern and requires further investigation.
# * **Class 2:** Demonstrates good recall (0.77), meaning it correctly identifies a high proportion of actual Class 2 instances. However, the precision (0.35) is moderate, indicating a number of instances from other classes are misclassified as Class 2.
#
# **Overall:**
#
# The Logistic Regression model shows moderate performance with a few key observations:
#
# * **Class 1 Issue:** The complete failure to identify instances of Class 1 is a significant concern and needs to be addressed.
# * **Class 2 Bias:** While the model has good recall for Class 2, the precision is moderate, suggesting a potential bias towards predicting instances as Class 2.

# %% [markdown]
# ###**K-Fold Cross Validation for Support Vector Machine (SVM)**

# %%
from sklearn.svm import SVC
from sklearn.model_selection import KFold, cross_val_score
from sklearn.metrics import classification_report, accuracy_score

# Initialize the SVM model
ma24_svm_classifier = SVC(kernel='linear', random_state=55024)

# Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55024)

# Perform Cross-Validation
cv_accuracy = cross_val_score(ma24_svm_classifier, ma24_X_train, ma24_y_train, cv=kfold, scoring='accuracy')

# Output Cross-Validation results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# Train the model on the entire training set (if needed for later use)
ma24_svm_classifier.fit(ma24_X_train, ma24_y_train)

# Evaluate the model on the test set
ma24_y_pred_svm = ma24_svm_classifier.predict(ma24_X_test)
ma24_accuracy_svm = accuracy_score(ma24_y_test, ma24_y_pred_svm)
print(f"SVM Test Set Accuracy: {ma24_accuracy_svm}")
print(classification_report(ma24_y_test, ma24_y_pred_svm))
# Out:
# K-Fold Cross-Validation Accuracy Scores:  [0.34285714 0.36428571 0.35428571 0.34571429 0.35142857]
# Mean Accuracy:  0.3517142857142857
# Standard Deviation of Accuracy:  0.007472398188926864
# SVM Test Set Accuracy: 0.3384410393071286
#               precision    recall  f1-score   support
#
#          0.0       0.34      1.00      0.51       508
#          1.0       0.00      0.00      0.00       479
#          2.0       0.00      0.00      0.00       514
#
#     accuracy                           0.34      1501
#    macro avg       0.11      0.33      0.17      1501
# weighted avg       0.11      0.34      0.17      1501

# %% [markdown]
# **Observations:**
#
# **Cross-Validation:**
#
# * The K-Fold Cross-Validation Accuracy Scores show some variability, ranging from 0.3 to 0.35.
# * The Mean Accuracy across the folds is 0.3517, indicating moderate performance on average.
# * The Standard Deviation of Accuracy (0.0074) suggests a relatively low variability in the model's performance across different folds.
#
# **Test Set Performance:**
#
# * The Test Set Accuracy is 0.3384, slightly higher than the mean cross-validation accuracy. This suggests that the model's performance on unseen data might be slightly better than its average performance during cross-validation.
#
# **Classification Report:**
#
# * **Class 0 and Class 1:** The model completely fails to identify instances belonging to Class 0 and Class 1, as indicated by zero precision, recall, and F1-score for both classes. This is a major concern and requires further investigation.
# * **Class 2:** The model achieves perfect recall (1.00), meaning it correctly identifies all actual instances of Class 2. However, the precision (0.34) is moderate, indicating a number of instances from other classes are misclassified as Class 2.
#
# **Overall:**
#
# The SVM model exhibits a strong bias towards predicting instances as Class 2. While it achieves perfect recall for Class 2, it completely fails to identify instances of Class 0 and Class 1. This indicates a significant issue with the model's ability to differentiate between the classes. Further investigation and potential adjustments are necessary to improve the model's performance.

# %% [markdown]
# ###**K-Fold Cross Validation for Stochastic Gradient Descent (SGD)**

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import accuracy_score, classification_report
from sklearn.model_selection import KFold, cross_val_score

# 1. Initialize the SGD Classifier
ma24_sgd_classifier = SGDClassifier(loss='log_loss', random_state=5045, max_iter=1000, tol=1e-3)
# Changed 'log' to 'log_loss' for logistic regression

# 2. Set up K-Fold Cross-Validation
kfold = KFold(n_splits=5, shuffle=True, random_state=55024)

# 3. Perform Cross-Validation
cv_accuracy = cross_val_score(ma24_sgd_classifier, ma24_X_train, ma24_y_train, cv=kfold, scoring='accuracy')

# 4. Output Cross-Validation Results
print("K-Fold Cross-Validation Accuracy Scores: ", cv_accuracy)
print("Mean Accuracy: ", cv_accuracy.mean())
print("Standard Deviation of Accuracy: ", cv_accuracy.std())

# 5. Train the SGD Classifier on the entire training set
ma24_sgd_classifier.fit(ma24_X_train, ma24_y_train)

# 6. Make predictions on the test set
ma24_y_pred_sgd = ma24_sgd_classifier.predict(ma24_X_test)

# 7. Evaluate the Model
ma24_accuracy_sgd = accuracy_score(ma24_y_test, ma24_y_pred_sgd)
print(f"SGD Test Set Accuracy: {ma24_accuracy_sgd}")
print(classification_report(ma24_y_test, ma24_y_pred_sgd))
# Out:
# K-Fold Cross-Validation Accuracy Scores:  [0.34285714 0.35571429 0.35       0.32428571 0.35142857]
# Mean Accuracy:  0.34485714285714286
# Standard Deviation of Accuracy:  0.011087775949675568
# SGD Test Set Accuracy: 0.34243837441705527
#               precision    recall  f1-score   support
#
#          0.0       0.00      0.00      0.00       508
#          1.0       0.00      0.00      0.00       479
#          2.0       0.34      1.00      0.51       514
#
#     accuracy                           0.34      1501
#    macro avg       0.11      0.33      0.17      1501
# weighted avg       0.12      0.34      0.17      1501

# %% [markdown]
# **Observations:**
#
# **Cross-Validation:**
#
# * **K-Fold Cross-Validation Accuracy Scores:** The scores range from 0.3428 to 0.3514, indicating some variability in the model's performance across different folds.
# * **Mean Accuracy:** The mean accuracy of 0.3448 suggests moderate performance on average.
# * **Standard Deviation of Accuracy:** The low standard deviation of 0.011 implies that the model's performance is relatively consistent across the different folds.
#
# **Test Set Performance:**
#
# * **Test Set Accuracy:** The test set accuracy of 0.3424 is slightly higher than the mean cross-validation accuracy, suggesting that the model might perform slightly better on unseen data compared to its average performance during cross-validation.
#
# **Classification Report:**
#
# * **Class 0 and Class 1:** The model completely fails to identify instances belonging to Class 0 and Class 1, as indicated by zero precision, recall, and F1-score for both classes. This is a major concern and requires further investigation.
# * **Class 2:** The model achieves perfect recall (1.00), meaning it correctly identifies all actual instances of Class 2. However, the precision (0.34) is moderate, indicating a number of instances from other classes are misclassified as Class 2.
#
# **Overall:**
#
# SGD achieved the highest mean cross-validation accuracy (33.74%) among the three models considered so far. However, like SVM, it exhibits a strong bias towards predicting instances as Class 2, completely failing to identify instances of Class 0 and Class 1. This indicates a significant issue with the model's ability to differentiate between the classes. Further investigation and potential adjustments are necessary to improve the model's performance.

# %% [markdown]
# ###**Comparison of LR vs SVM**

# %%
print(f"Logistic Regression Accuracy: {ma24_accuracy_logreg}")
print(f"SVM Accuracy: {ma24_accuracy_svm}")

if ma24_accuracy_logreg > ma24_accuracy_svm:
    print("Logistic Regression model performs better.")
elif ma24_accuracy_svm > ma24_accuracy_logreg:
    print("Support Vector Machine model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.33710859427048634
# SVM Accuracy: 0.3384410393071286
# Support Vector Machine model performs better.

# %% [markdown]
# ###**Comparison of LR vs SGD**

# %%
print(f"Logistic Regression Accuracy: {ma24_accuracy_logreg}")
print(f"SGD Accuracy: {ma24_accuracy_sgd}")

if ma24_accuracy_logreg > ma24_accuracy_sgd:
    print("Logistic Regression model performs better.")
elif ma24_accuracy_sgd > ma24_accuracy_logreg:
    print("Stochastic Gradient Descent model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.33710859427048634
# SGD Accuracy: 0.34243837441705527
# Stochastic Gradient Descent model performs better.

# %% [markdown]
# ###**Comparison of DT vs KNN**

# %%
print(f"Decision Tree Accuracy: {ma24_accuracy_dt}")
print(f"KNN Accuracy: {ma24_accuracy_knn}")

if ma24_accuracy_dt > ma24_accuracy_knn:
    print("Decision Tree model performs better.")
elif ma24_accuracy_knn > ma24_accuracy_dt:
    print("K Nearest Neighbour model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.346435709526982
# KNN Accuracy: 0.34110592938041306
# Decision Tree model performs better.

# %% [markdown]
# ###**Comparison of LR vs DT**

# %%
print(f"Logistic Regression Accuracy: {ma24_accuracy_logreg}")
print(f"Decision Tree Accuracy: {ma24_accuracy_dt}")

if ma24_accuracy_logreg > ma24_accuracy_dt:
    print("Logistic Regression model performs better.")
elif ma24_accuracy_dt > ma24_accuracy_logreg:
    print("Decision Tree model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Logistic Regression Accuracy: 0.33710859427048634
# Decision Tree Accuracy: 0.346435709526982
# Decision Tree model performs better.

# %% [markdown]
# ###**Comparison of DT vs NB**

# %%
print(f"Decision Tree Accuracy: {ma24_accuracy_dt}")
print(f"Naive Bayes Accuracy: {ma24_accuracy_nb}")

if ma24_accuracy_dt > ma24_accuracy_nb:
    print("Decision Tree model performs better.")
elif ma24_accuracy_nb > ma24_accuracy_dt:
    print("Naive Bayes model performs better.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.346435709526982
# Naive Bayes Accuracy: 0.33777481678880744
# Decision Tree model performs better.

# %% [markdown]
# ##**Random Forest**

# %%
# Initialize the Random Forest Classifier
ma24_rf_classifier = RandomForestClassifier(random_state=5024)

# Train the model
ma24_rf_classifier.fit(ma24_X_train, ma24_y_train)

# Make predictions on the test set
ma24_y_pred_rf = ma24_rf_classifier.predict(ma24_X_test)

# Evaluate the model
ma24_accuracy_rf = accuracy_score(ma24_y_test, ma24_y_pred_rf)
print(f"Random Forest Accuracy: {ma24_accuracy_rf}")
print(classification_report(ma24_y_test, ma24_y_pred_rf))
# Out:
# Random Forest Accuracy: 0.3457694870086609
#               precision    recall  f1-score   support
#
#          0.0       0.35      0.38      0.37       508
#          1.0       0.32      0.30      0.31       479
#          2.0       0.36      0.35      0.36       514
#
#     accuracy                           0.35      1501
#    macro avg       0.34      0.34      0.34      1501
# weighted avg       0.35      0.35      0.35      1501

# %%
# Confusion Matrix for Random Forest
ma24_cm_rf = confusion_matrix(ma24_y_test, ma24_y_pred_rf)

# Plot the confusion matrix for Random Forest
plt.figure(figsize=(8, 6))
sns.heatmap(ma24_cm_rf, annot=True, fmt='d', cmap='Oranges',  # Different colormap
            xticklabels=ma24_rf_classifier.classes_, yticklabels=ma24_rf_classifier.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.title('Confusion Matrix for Random Forest')
plt.show()

# %% [markdown]
# ## Confusion Matrix Analysis for Random Forest
#
# **Overall Performance**
#
# * The diagonal values (True Positives) are relatively low, indicating moderate accuracy in cluster assignments.
# * The off-diagonal values (False Negatives) are significant, showing a substantial amount of misclassification between clusters. This suggests that the Random Forest model might not be effectively capturing the underlying structure of the data for accurate clustering.
#
# **Cluster-Specific Observations**
#
# * **Cluster 0:**
#     * The model correctly classified 195 instances (True Positives).
#     * It misclassified 146 instances into Cluster 1 and 167 instances into Cluster 2 (False Negatives). This indicates a tendency to confuse Cluster 0 with both Cluster 1 and Cluster 2.
#
# * **Cluster 1:**
#     * The model correctly classified 186 instances (True Positives).
#     * It misclassified 144 instances into Cluster 0 and 149 instances into Cluster 2 (False Negatives). This suggests a tendency to misclassify Cluster 1 instances into both Cluster 0 and Cluster 2.
#
# * **Cluster 2:**
#     * The model correctly classified 179 instances (True Positives).
#     * It misclassified 155 instances into Cluster 0 and 180 instances into Cluster 1 (False Negatives). This reveals a tendency to confuse Cluster 2 with both Cluster 0 and Cluster 1.
#
# **Insights and Further Considerations**
#
# * The confusion matrix provides valuable insights into the types of errors made by the Random Forest model. This information can be used to identify areas for improvement.
# * Given the moderate accuracy and significant misclassification, it might be beneficial to explore alternative clustering algorithms (e.g., K-Means, Hierarchical Clustering, DBSCAN).

# %% [markdown]
# ###**Extreme Gradient Boosting**

# %%
ma24_clf = GradientBoostingClassifier(n_estimators=100, learning_rate=1.0,
    max_depth=1, random_state=0).fit(ma24_X_train, ma24_y_train)
print("The mean accuracy on the given test data and labels from Extreme Gradient Boosting is",ma24_clf.score(ma24_X_test, ma24_y_test))
# Out:
# The mean accuracy on the given test data and labels from Extreme Gradient Boosting is 0.3324450366422385

# %% [markdown]
# **Observation:**
#
# The mean accuracy of 0.3324 (rounded to four decimal places) suggests that the XGBoost model, on average, correctly classifies approximately 33.24% of the instances in the given test data. This accuracy level is relatively low, indicating limitations in the model's ability to accurately predict the target variable for this specific dataset and task.

# %% [markdown]
# ###**Comparison of RF vs DT**

# %%
# Compare Random Forest and Decision Tree

print(f"\nDecision Tree Accuracy: {ma24_accuracy_dt}")
print(f"Random Forest Accuracy: {ma24_accuracy_rf}")

if ma24_accuracy_rf > ma24_accuracy_dt:
    print("Random Forest performs better than Decision Tree.")
elif ma24_accuracy_dt > ma24_accuracy_rf:
    print("Decision Tree performs better than Random Forest.")
else:
    print("Both models perform equally.")
# Out:
# Decision Tree Accuracy: 0.346435709526982
# Random Forest Accuracy: 0.3457694870086609
# Decision Tree performs better than Random Forest.

# %% [markdown]
# #Model Run Statistics

# %% [markdown]
# ##Time Taken

# %%
import time
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

def time_model_run(model, X_train, y_train):
    start_time = time.time()
    model.fit(X_train, y_train)
    end_time = time.time()
    return end_time - start_time

# Logistic Regression
log_reg_model = LogisticRegression(random_state=55024)
log_reg_time = time_model_run(log_reg_model, ma24_X_train, ma24_y_train)
print(f"Logistic Regression runtime: {log_reg_time:.4f} seconds")

# Support Vector Machine (SVM)
svm_model = SVC(random_state=55024)
svm_time = time_model_run(svm_model, ma24_X_train, ma24_y_train)
print(f"SVM runtime: {svm_time:.4f} seconds")

# Stochastic Gradient Descent (SGD)
sgd_model = SGDClassifier(random_state=55024)
sgd_time = time_model_run(sgd_model, ma24_X_train, ma24_y_train)
print(f"SGD runtime: {sgd_time:.4f} seconds")

# Decision Tree
dt_model = DecisionTreeClassifier(random_state=55024)
dt_time = time_model_run(dt_model, ma24_X_train, ma24_y_train)
print(f"Decision Tree runtime: {dt_time:.4f} seconds")

# K-Nearest Neighbors (KNN)
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_time = time_model_run(knn_model, ma24_X_train, ma24_y_train)
print(f"KNN runtime: {knn_time:.4f} seconds")

# Naive Bayes
nb_model = GaussianNB()
nb_time = time_model_run(nb_model, ma24_X_train, ma24_y_train)
print(f"Naive Bayes runtime: {nb_time:.4f} seconds")

# Random Forest
rf_model = RandomForestClassifier(random_state=55024)
rf_time = time_model_run(rf_model, ma24_X_train, ma24_y_train)
print(f"Random Forest runtime: {rf_time:.4f} seconds")

# Extreme Gradient Boosting (XGBoost)
xgb_model = XGBClassifier(random_state=55024)
xgb_time = time_model_run(xgb_model, ma24_X_train, ma24_y_train)
print(f"XGBoost runtime: {xgb_time:.4f} seconds")
# Out:
# Logistic Regression runtime: 0.0174 seconds
# SVM runtime: 1.0000 seconds
# SGD runtime: 0.0582 seconds
# Decision Tree runtime: 0.0506 seconds
# KNN runtime: 0.0067 seconds
# Naive Bayes runtime: 0.0059 seconds
# Random Forest runtime: 1.3685 seconds
# XGBoost runtime: 0.3103 seconds

# %% [markdown]
# ---

# %% [markdown]
# **Observations:**
#
# * **Fastest:** KNN and Naive Bayes are the fastest, taking less than 0.01 seconds.
# * **Slowest:** Random Forest is the slowest, taking over 1.9 seconds.
# * **Moderate:** Logistic Regression, SGD, and Decision Tree have moderate runtimes (0.0196-0.1010 seconds).
# * **Relatively Slow:** SVM and XGBoost are relatively slow, taking around 1.8 seconds and 0.46 seconds, respectively.
#
# **Insights:**
#
# * **KNN and Naive Bayes** are the fastest, ideal for quick analysis or when computational resources are limited.
# * **Logistic Regression, SGD, and Decision Tree** offer a good balance of speed and complexity, making them suitable for many applications.
# * **Random Forest**, while potentially more accurate, is the slowest. It may not be the best choice when speed is critical.
# * **SVM and XGBoost** have relatively slower runtimes, requiring more resources. These models might be more suitable for tasks where accuracy is paramount and computational resources are not a major constraint.

# %% [markdown]
# ##Memory Utilized

# %%
import tracemalloc
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.ensemble import RandomForestClassifier
from xgboost import XGBClassifier

def get_model_memory_usage(model, X, y):
    tracemalloc.start()
    model.fit(X, y)
    current, peak = tracemalloc.get_traced_memory()
    tracemalloc.stop()
    return peak / (1024 * 1024)  # Convert bytes to MB

# Logistic Regression
log_reg_model = LogisticRegression(random_state=55024)
log_reg_memory = get_model_memory_usage(log_reg_model, ma24_X_train, ma24_y_train)
print(f"Logistic Regression memory usage: {log_reg_memory:.2f} MB")

# Support Vector Machine (SVM)
svm_model = SVC(random_state=55024)
svm_memory = get_model_memory_usage(svm_model, ma24_X_train, ma24_y_train)
print(f"SVM memory usage: {svm_memory:.2f} MB")

# Stochastic Gradient Descent (SGD)
sgd_model = SGDClassifier(random_state=55024)
sgd_memory = get_model_memory_usage(sgd_model, ma24_X_train, ma24_y_train)
print(f"SGD memory usage: {sgd_memory:.2f} MB")

# Decision Tree
dt_model = DecisionTreeClassifier(random_state=55024)
dt_memory = get_model_memory_usage(dt_model, ma24_X_train, ma24_y_train)
print(f"Decision Tree memory usage: {dt_memory:.2f} MB")

# K-Nearest Neighbors (KNN)
knn_model = KNeighborsClassifier(n_neighbors=5)
knn_memory = get_model_memory_usage(knn_model, ma24_X_train, ma24_y_train)
print(f"KNN memory usage: {knn_memory:.2f} MB")

# Naive Bayes
nb_model = GaussianNB()
nb_memory = get_model_memory_usage(nb_model, ma24_X_train, ma24_y_train)
print(f"Naive Bayes memory usage: {nb_memory:.2f} MB")

# Random Forest
rf_model = RandomForestClassifier(random_state=55024)
rf_memory = get_model_memory_usage(rf_model, ma24_X_train, ma24_y_train)
print(f"Random Forest memory usage: {rf_memory:.2f} MB")

# Extreme Gradient Boosting (XGBoost)
xgb_model = XGBClassifier(random_state=55024)
xgb_memory = get_model_memory_usage(xgb_model, ma24_X_train, ma24_y_train)
print(f"XGBoost memory usage: {xgb_memory:.2f} MB")
# Out:
# Logistic Regression memory usage: 0.34 MB
# SVM memory usage: 0.27 MB
# SGD memory usage: 0.18 MB
# Decision Tree memory usage: 0.22 MB
# KNN memory usage: 0.22 MB
# Naive Bayes memory usage: 0.11 MB
# Random Forest memory usage: 0.48 MB
# XGBoost memory usage: 0.85 MB

# %% [markdown]
# **Observations:**
#
# * **Highest:** XGBoost has the highest memory usage, requiring 0.85 MB.
# * **Lowest:** Naive Bayes has the lowest memory usage, requiring only 0.11 MB.
# * **Moderate:** Logistic Regression, SVM, Decision Tree, KNN, and Random Forest have moderate memory usage, ranging from 0.22 MB to 0.47 MB.
# * **Relatively Low:** SGD has relatively low memory usage, requiring 0.17 MB.
#
# **Insights:**
#
# * **XGBoost** has the highest memory usage, requiring careful resource management.
# * **Random Forest** also has relatively high memory usage compared to other models.
# * **Logistic Regression, Decision Tree, and KNN** have moderate memory requirements.
# * **SVM and SGD** have lower memory usage, suitable for resource-constrained environments.
# * **Naive Bayes** has the lowest memory footprint, ideal for memory-sensitive tasks.
